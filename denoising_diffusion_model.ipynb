# %% [markdown]
# ### Denoising Diffusion Model using 10 different posterior approximations corresponding to different noise levels obtained in multiple_denois.ipynb

# %%
import json

# Define the paths to the JSON files
output_file_path_1 = 'output/output_dict_noise_005.json'
output_file_path_2 = 'output/output_dict_noise_01.json'
output_file_path_3 = 'output/output_dict_noise_015.json'
output_file_path_4 = 'output/output_dict_noise_02.json'
output_file_path_5 = 'output/output_dict_noise_025.json'
output_file_path_6 = 'output/output_dict_noise_03.json'
output_file_path_7 = 'output/output_dict_noise_035.json'
output_file_path_8 = 'output/output_dict_noise_04.json'
output_file_path_9 = 'output/output_dict_noise_045.json'
output_file_path_10 = 'output/output_dict_noise_05.json'

# Load the content of the JSON files into corresponding dictionaries
with open(output_file_path_1, 'r') as f:
    output_dict_loaded_1 = json.load(f)

with open(output_file_path_2, 'r') as f:
    output_dict_loaded_2 = json.load(f)

with open(output_file_path_3, 'r') as f:
    output_dict_loaded_3 = json.load(f)

with open(output_file_path_4, 'r') as f:
    output_dict_loaded_4 = json.load(f)
    
with open(output_file_path_5, 'r') as f:
    output_dict_loaded_5 = json.load(f)
    
with open(output_file_path_6, 'r') as f:
    output_dict_loaded_6 = json.load(f)
    
with open(output_file_path_7, 'r') as f:
    output_dict_loaded_7 = json.load(f)

with open(output_file_path_8, 'r') as f:
    output_dict_loaded_8 = json.load(f)    

with open(output_file_path_9, 'r') as f:
    output_dict_loaded_9 = json.load(f)
    
with open(output_file_path_10, 'r') as f:
    output_dict_loaded_10 = json.load(f)   
    
    
# Display the loaded dictionaries
print("output_dict_loaded_1")
print("output_dict_loaded_2")
print("output_dict_loaded_3")
print("output_dict_loaded_4")
print("output_dict_loaded_5")
print("output_dict_loaded_6")
print("output_dict_loaded_7")
print("output_dict_loaded_8")
print("output_dict_loaded_9")
print("output_dict_loaded_10")
# Out:
# output_dict_loaded_1
# output_dict_loaded_2
# output_dict_loaded_3
# output_dict_loaded_4
# output_dict_loaded_5
# output_dict_loaded_6
# output_dict_loaded_7
# output_dict_loaded_8
# output_dict_loaded_9
# output_dict_loaded_10

# %%
import torch

# Define a function to convert lists to tensors
def list_to_tensor(obj):
    if isinstance(obj, list):
        # Convert the list to a tensor
        return torch.tensor(obj)
    else:
        return obj  

# Iterate over keys of output_dict_loaded_1
for key, value in output_dict_loaded_1.items():
    # Check if the key is 'all_weights' or 'all_samples'
    if key in ['all_weights', 'all_samples']:
        # Convert the corresponding list to a tensor
        output_dict_loaded_1[key] = list_to_tensor(value)

# Iterate over keys of output_dict_loaded_2
for key, value in output_dict_loaded_2.items():
    # Check if the key is 'all_weights' or 'all_samples'
    if key in ['all_weights', 'all_samples']:
        # Convert the corresponding list to a tensor
        output_dict_loaded_2[key] = list_to_tensor(value)

# Iterate over keys of output_dict_loaded_3
for key, value in output_dict_loaded_3.items():
    # Check if the key is 'all_weights' or 'all_samples'
    if key in ['all_weights', 'all_samples']:
        # Convert the corresponding list to a tensor
        output_dict_loaded_3[key] = list_to_tensor(value)

# Iterate over keys of output_dict_loaded_4
for key, value in output_dict_loaded_4.items():
    # Check if the key is 'all_weights' or 'all_samples'
    if key in ['all_weights', 'all_samples']:
        # Convert the corresponding list to a tensor
        output_dict_loaded_4[key] = list_to_tensor(value)

# Iterate over keys of output_dict_loaded_5
for key, value in output_dict_loaded_5.items():
    # Check if the key is 'all_weights' or 'all_samples'
    if key in ['all_weights', 'all_samples']:
        # Convert the corresponding list to a tensor
        output_dict_loaded_5[key] = list_to_tensor(value)
        
# Iterate over keys of output_dict_loaded_6
for key, value in output_dict_loaded_6.items():
    # Check if the key is 'all_weights' or 'all_samples'
    if key in ['all_weights', 'all_samples']:
        # Convert the corresponding list to a tensor
        output_dict_loaded_6[key] = list_to_tensor(value)
        
# Iterate over keys of output_dict_loaded_7
for key, value in output_dict_loaded_7.items():
    # Check if the key is 'all_weights' or 'all_samples'
    if key in ['all_weights', 'all_samples']:
        # Convert the corresponding list to a tensor
        output_dict_loaded_7[key] = list_to_tensor(value)
        
# Iterate over keys of output_dict_loaded_8
for key, value in output_dict_loaded_8.items():
    # Check if the key is 'all_weights' or 'all_samples'
    if key in ['all_weights', 'all_samples']:
        # Convert the corresponding list to a tensor
        output_dict_loaded_8[key] = list_to_tensor(value)
        
# Iterate over keys of output_dict_loaded_9
for key, value in output_dict_loaded_9.items():
    # Check if the key is 'all_weights' or 'all_samples'
    if key in ['all_weights', 'all_samples']:
        # Convert the corresponding list to a tensor
        output_dict_loaded_9[key] = list_to_tensor(value)
                
# Iterate over keys of output_dict_loaded_10
for key, value in output_dict_loaded_10.items():
    # Check if the key is 'all_weights' or 'all_samples'
    if key in ['all_weights', 'all_samples']:
        # Convert the corresponding list to a tensor
        output_dict_loaded_10[key] = list_to_tensor(value)

# Verify the conversion by printing a message
print("Modified output_dict_loaded_1, output_dict_loaded_2, and output_dict_loaded_3 done")
# Out:
# Modified output_dict_loaded_1, output_dict_loaded_2, and output_dict_loaded_3 done

# %%
# get samples and weights from output_dict_loaded_1
samples_vector_1 = output_dict_loaded_1['all_samples']
weights_vector_1 = output_dict_loaded_1['all_weights']

# get samples and weights from output_dict_loaded_2
samples_vector_2 = output_dict_loaded_2['all_samples']
weights_vector_2 = output_dict_loaded_2['all_weights']

# get samples and weights from output_dict_loaded_3
samples_vector_3 = output_dict_loaded_3['all_samples']
weights_vector_3 = output_dict_loaded_3['all_weights']

# get samples and weights from output_dict_loaded_4
samples_vector_4 = output_dict_loaded_4['all_samples']
weights_vector_4 = output_dict_loaded_4['all_weights']

# get samples and weights from output_dict_loaded_5
samples_vector_5 = output_dict_loaded_5['all_samples']
weights_vector_5 = output_dict_loaded_5['all_weights']

# get samples and weights from output_dict_loaded_6
samples_vector_6 = output_dict_loaded_6['all_samples']
weights_vector_6 = output_dict_loaded_6['all_weights']

# get samples and weights from output_dict_loaded_7
samples_vector_7 = output_dict_loaded_7['all_samples']
weights_vector_7 = output_dict_loaded_7['all_weights']

# get samples and weights from output_dict_loaded_8
samples_vector_8 = output_dict_loaded_8['all_samples']
weights_vector_8 = output_dict_loaded_8['all_weights']

# get samples and weights from output_dict_loaded_9
samples_vector_9 = output_dict_loaded_9['all_samples']
weights_vector_9 = output_dict_loaded_9['all_weights']

# get samples and weights from output_dict_loaded_10
samples_vector_10 = output_dict_loaded_10['all_samples']
weights_vector_10 = output_dict_loaded_10['all_weights']

# Extract the last row from the weights vectors
weights_1 = weights_vector_1[-1, :]
weights_2 = weights_vector_2[-1, :]
weights_3 = weights_vector_3[-1, :]
weights_4 = weights_vector_1[-1, :]
weights_5 = weights_vector_2[-1, :]
weights_6 = weights_vector_3[-1, :]
weights_7 = weights_vector_1[-1, :]
weights_8 = weights_vector_2[-1, :]
weights_9 = weights_vector_3[-1, :]
weights_10 = weights_vector_3[-1, :]

# Extract the last slice from the samples vectors
samples_1 = samples_vector_1[-1, :, :]
samples_2 = samples_vector_2[-1, :, :]
samples_3 = samples_vector_3[-1, :, :]
samples_4 = samples_vector_4[-1, :, :]
samples_5 = samples_vector_5[-1, :, :]
samples_6 = samples_vector_6[-1, :, :]
samples_7 = samples_vector_7[-1, :, :]
samples_8 = samples_vector_8[-1, :, :]
samples_9 = samples_vector_9[-1, :, :]
samples_10 = samples_vector_10[-1, :, :]

# %%
from functions import *
import numpy as np
from DenoisingNetwork import ConvDenoiser   

# Define the number of resampled iterations
N_resampled = 2
N = 10
K = 10

# Ensure weights are not NaN and normalize them
weights_1 = np.nan_to_num(weights_1)
weights_2 = np.nan_to_num(weights_2)
weights_3 = np.nan_to_num(weights_3)
weights_4 = np.nan_to_num(weights_4)
weights_5 = np.nan_to_num(weights_5)
weights_6 = np.nan_to_num(weights_6)
weights_7 = np.nan_to_num(weights_7)
weights_8 = np.nan_to_num(weights_8)
weights_9 = np.nan_to_num(weights_9)
weights_10 = np.nan_to_num(weights_10)

wn_1 = weights_1 / sum(weights_1)
wn_2 = weights_2 / sum(weights_2)
wn_3 = weights_3 / sum(weights_3)
wn_4 = weights_4 / sum(weights_4)
wn_5 = weights_5 / sum(weights_5)
wn_6 = weights_6 / sum(weights_6)
wn_7 = weights_7 / sum(weights_7)
wn_8 = weights_8 / sum(weights_8)
wn_9 = weights_9 / sum(weights_9)
wn_10 = weights_10 / sum(weights_10)

# Randomly select positions based on the resampled weights
positions_1 = np.random.choice([i for i in range(N * K)], N_resampled, replace=True, p=wn_1)
positions_2 = np.random.choice([i for i in range(N * K)], N_resampled, replace=True, p=wn_2)
positions_3 = np.random.choice([i for i in range(N * K)], N_resampled, replace=True, p=wn_3)
positions_4 = np.random.choice([i for i in range(N * K)], N_resampled, replace=True, p=wn_1)
positions_5 = np.random.choice([i for i in range(N * K)], N_resampled, replace=True, p=wn_2)
positions_6 = np.random.choice([i for i in range(N * K)], N_resampled, replace=True, p=wn_3)
positions_7 = np.random.choice([i for i in range(N * K)], N_resampled, replace=True, p=wn_1)
positions_8 = np.random.choice([i for i in range(N * K)], N_resampled, replace=True, p=wn_2)
positions_9 = np.random.choice([i for i in range(N * K)], N_resampled, replace=True, p=wn_3)
positions_10 = np.random.choice([i for i in range(N * K)], N_resampled, replace=True, p=wn_3)

# Extract parameter vectors for each model
parameter_vec_1_1 = samples_1[:, positions_1[0]]
parameter_vec_1_2 = samples_1[:, positions_1[1]]
parameter_vec_2_1 = samples_2[:, positions_2[0]]
parameter_vec_2_2 = samples_2[:, positions_2[1]]
parameter_vec_3_1 = samples_3[:, positions_3[0]]
parameter_vec_3_2 = samples_3[:, positions_3[1]]
parameter_vec_4_1 = samples_4[:, positions_4[0]]
parameter_vec_4_2 = samples_4[:, positions_4[1]]
parameter_vec_5_1 = samples_5[:, positions_5[0]]
parameter_vec_5_2 = samples_5[:, positions_5[1]]
parameter_vec_6_1 = samples_6[:, positions_6[0]]
parameter_vec_6_2 = samples_6[:, positions_6[1]]
parameter_vec_7_1 = samples_7[:, positions_7[0]]
parameter_vec_7_2 = samples_7[:, positions_7[1]]
parameter_vec_8_1 = samples_8[:, positions_8[0]]
parameter_vec_8_2 = samples_8[:, positions_8[1]]
parameter_vec_9_1 = samples_9[:, positions_9[0]]
parameter_vec_9_2 = samples_9[:, positions_9[1]]
parameter_vec_10_1 = samples_10[:, positions_10[0]]
parameter_vec_10_2 = samples_10[:, positions_10[1]]


# Convert parameter vectors to weights and biases
[W_1_1, b_1_1] = Vec2param(parameter_vec_1_1)
[W_1_2, b_1_2] = Vec2param(parameter_vec_1_2)
[W_2_1, b_2_1] = Vec2param(parameter_vec_2_1)
[W_2_2, b_2_2] = Vec2param(parameter_vec_2_2)
[W_3_1, b_3_1] = Vec2param(parameter_vec_3_1)
[W_3_2, b_3_2] = Vec2param(parameter_vec_3_2)
[W_4_1, b_4_1] = Vec2param(parameter_vec_4_1)
[W_4_2, b_4_2] = Vec2param(parameter_vec_4_2)
[W_5_1, b_5_1] = Vec2param(parameter_vec_5_1)
[W_5_2, b_5_2] = Vec2param(parameter_vec_5_2)
[W_6_1, b_6_1] = Vec2param(parameter_vec_6_1)
[W_6_2, b_6_2] = Vec2param(parameter_vec_6_2)
[W_7_1, b_7_1] = Vec2param(parameter_vec_7_1)
[W_7_2, b_7_2] = Vec2param(parameter_vec_7_2)
[W_8_1, b_8_1] = Vec2param(parameter_vec_8_1)
[W_8_2, b_8_2] = Vec2param(parameter_vec_8_2)
[W_9_1, b_9_1] = Vec2param(parameter_vec_9_1)
[W_9_2, b_9_2] = Vec2param(parameter_vec_9_2)
[W_10_1, b_10_1] = Vec2param(parameter_vec_10_1)
[W_10_2, b_10_2] = Vec2param(parameter_vec_10_2)


# Instantiate the ConvDenoiser models
model_1_1 = ConvDenoiser()
model_1_2 = ConvDenoiser()
model_2_1 = ConvDenoiser()
model_2_2 = ConvDenoiser()
model_3_1 = ConvDenoiser()
model_3_2 = ConvDenoiser()
model_4_1 = ConvDenoiser()
model_4_2 = ConvDenoiser()
model_5_1 = ConvDenoiser()
model_5_2 = ConvDenoiser()
model_6_1 = ConvDenoiser()
model_6_2 = ConvDenoiser()
model_7_1 = ConvDenoiser()
model_7_2 = ConvDenoiser()
model_8_1 = ConvDenoiser()
model_8_2 = ConvDenoiser()
model_9_1 = ConvDenoiser()
model_9_2 = ConvDenoiser()
model_10_1 = ConvDenoiser()
model_10_2 = ConvDenoiser()

# Load weights and biases into each model
# For model_1_1
model_1_1.conv1.weight.data = W_1_1['conv1']
model_1_1.conv1.bias.data = b_1_1['conv1']
model_1_1.conv2.weight.data = W_1_1['conv2']
model_1_1.conv2.bias.data = b_1_1['conv2']
model_1_1.conv3.weight.data = W_1_1['conv3']
model_1_1.conv3.bias.data = b_1_1['conv3']
model_1_1.t_conv1.weight.data = W_1_1['t_conv1']
model_1_1.t_conv1.bias.data = b_1_1['t_conv1']
model_1_1.t_conv2.weight.data = W_1_1['t_conv2']
model_1_1.t_conv3.weight.data = W_1_1['t_conv3']
model_1_1.conv_out.weight.data = W_1_1['conv_out']
model_1_1.conv_out.bias.data = b_1_1['conv_out']

# For model_1_2
model_1_2.conv1.weight.data = W_1_2['conv1']
model_1_2.conv1.bias.data = b_1_2['conv1']
model_1_2.conv2.weight.data = W_1_2['conv2']
model_1_2.conv2.bias.data = b_1_2['conv2']
model_1_2.conv3.weight.data = W_1_2['conv3']
model_1_2.conv3.bias.data = b_1_2['conv3']
model_1_2.t_conv1.weight.data = W_1_2['t_conv1']
model_1_2.t_conv1.bias.data = b_1_2['t_conv1']
model_1_2.t_conv2.weight.data = W_1_2['t_conv2']
model_1_2.t_conv3.weight.data = W_1_2['t_conv3']
model_1_2.conv_out.weight.data = W_1_2['conv_out']
model_1_2.conv_out.bias.data = b_1_2['conv_out']

# For model_2_1
model_2_1.conv1.weight.data = W_2_1['conv1']
model_2_1.conv1.bias.data = b_2_1['conv1']
model_2_1.conv2.weight.data = W_2_1['conv2']
model_2_1.conv2.bias.data = b_2_1['conv2']
model_2_1.conv3.weight.data = W_2_1['conv3']
model_2_1.conv3.bias.data = b_2_1['conv3']
model_2_1.t_conv1.weight.data = W_2_1['t_conv1']
model_2_1.t_conv1.bias.data = b_2_1['t_conv1']
model_2_1.t_conv2.weight.data = W_2_1['t_conv2']
model_2_1.t_conv3.weight.data = W_2_1['t_conv3']
model_2_1.conv_out.weight.data = W_2_1['conv_out']
model_2_1.conv_out.bias.data = b_2_1['conv_out']

# For model_2_2
model_2_2.conv1.weight.data = W_2_2['conv1']
model_2_2.conv1.bias.data = b_2_2['conv1']
model_2_2.conv2.weight.data = W_2_2['conv2']
model_2_2.conv2.bias.data = b_2_2['conv2']
model_2_2.conv3.weight.data = W_2_2['conv3']
model_2_2.conv3.bias.data = b_2_2['conv3']
model_2_2.t_conv1.weight.data = W_2_2['t_conv1']
model_2_2.t_conv1.bias.data = b_2_2['t_conv1']
model_2_2.t_conv2.weight.data = W_2_2['t_conv2']
model_2_2.t_conv3.weight.data = W_2_2['t_conv3']
model_2_2.conv_out.weight.data = W_2_2['conv_out']
model_2_2.conv_out.bias.data = b_2_2['conv_out']

# For model_3_1
model_3_1.conv1.weight.data = W_3_1['conv1']
model_3_1.conv1.bias.data = b_3_1['conv1']
model_3_1.conv2.weight.data = W_3_1['conv2']
model_3_1.conv2.bias.data = b_3_1['conv2']
model_3_1.conv3.weight.data = W_3_1['conv3']
model_3_1.conv3.bias.data = b_3_1['conv3']
model_3_1.t_conv1.weight.data = W_3_1['t_conv1']
model_3_1.t_conv1.bias.data = b_3_1['t_conv1']
model_3_1.t_conv2.weight.data = W_3_1['t_conv2']
model_3_1.t_conv3.weight.data = W_3_1['t_conv3']
model_3_1.conv_out.weight.data = W_3_1['conv_out']
model_3_1.conv_out.bias.data = b_3_1['conv_out']

# For model_3_2
model_3_2.conv1.weight.data = W_3_2['conv1']
model_3_2.conv1.bias.data = b_3_2['conv1']
model_3_2.conv2.weight.data = W_3_2['conv2']
model_3_2.conv2.bias.data = b_3_2['conv2']
model_3_2.conv3.weight.data = W_3_2['conv3']
model_3_2.conv3.bias.data = b_3_2['conv3']
model_3_2.t_conv1.weight.data = W_3_2['t_conv1']
model_3_2.t_conv1.bias.data = b_3_2['t_conv1']
model_3_2.t_conv2.weight.data = W_3_2['t_conv2']
model_3_2.t_conv3.weight.data = W_3_2['t_conv3']
model_3_2.conv_out.weight.data = W_3_2['conv_out']
model_3_2.conv_out.bias.data = b_3_2['conv_out']

# For model_4_1
model_4_1.conv1.weight.data = W_4_1['conv1']
model_4_1.conv1.bias.data = b_4_1['conv1']
model_4_1.conv2.weight.data = W_4_1['conv2']
model_4_1.conv2.bias.data = b_4_1['conv2']
model_4_1.conv3.weight.data = W_4_1['conv3']
model_4_1.conv3.bias.data = b_4_1['conv3']
model_4_1.t_conv1.weight.data = W_4_1['t_conv1']
model_4_1.t_conv1.bias.data = b_4_1['t_conv1']
model_4_1.t_conv2.weight.data = W_4_1['t_conv2']
model_4_1.t_conv3.weight.data = W_4_1['t_conv3']
model_4_1.conv_out.weight.data = W_4_1['conv_out']
model_4_1.conv_out.bias.data = b_4_1['conv_out']

# For model_4_2
model_4_2.conv1.weight.data = W_4_2['conv1']
model_4_2.conv1.bias.data = b_4_2['conv1']
model_4_2.conv2.weight.data = W_4_2['conv2']
model_4_2.conv2.bias.data = b_4_2['conv2']
model_4_2.conv3.weight.data = W_4_2['conv3']
model_4_2.conv3.bias.data = b_4_2['conv3']
model_4_2.t_conv1.weight.data = W_4_2['t_conv1']
model_4_2.t_conv1.bias.data = b_4_2['t_conv1']
model_4_2.t_conv2.weight.data = W_4_2['t_conv2']
model_4_2.t_conv3.weight.data = W_4_2['t_conv3']
model_4_2.conv_out.weight.data = W_4_2['conv_out']
model_4_2.conv_out.bias.data = b_4_2['conv_out']

# For model_5_1
model_5_1.conv1.weight.data = W_5_1['conv1']
model_5_1.conv1.bias.data = b_5_1['conv1']
model_5_1.conv2.weight.data = W_5_1['conv2']
model_5_1.conv2.bias.data = b_5_1['conv2']
model_5_1.conv3.weight.data = W_5_1['conv3']
model_5_1.conv3.bias.data = b_5_1['conv3']
model_5_1.t_conv1.weight.data = W_5_1['t_conv1']
model_5_1.t_conv1.bias.data = b_5_1['t_conv1']
model_5_1.t_conv2.weight.data = W_5_1['t_conv2']
model_5_1.t_conv3.weight.data = W_5_1['t_conv3']
model_5_1.conv_out.weight.data = W_5_1['conv_out']
model_5_1.conv_out.bias.data = b_5_1['conv_out']

# For model_5_2
model_5_2.conv1.weight.data = W_5_2['conv1']
model_5_2.conv1.bias.data = b_5_2['conv1']
model_5_2.conv2.weight.data = W_5_2['conv2']
model_5_2.conv2.bias.data = b_5_2['conv2']
model_5_2.conv3.weight.data = W_5_2['conv3']
model_5_2.conv3.bias.data = b_5_2['conv3']
model_5_2.t_conv1.weight.data = W_5_2['t_conv1']
model_5_2.t_conv1.bias.data = b_5_2['t_conv1']
model_5_2.t_conv2.weight.data = W_5_2['t_conv2']
model_5_2.t_conv3.weight.data = W_5_2['t_conv3']
model_5_2.conv_out.weight.data = W_5_2['conv_out']
model_5_2.conv_out.bias.data = b_5_2['conv_out']

# For model_6_1
model_6_1.conv1.weight.data = W_6_1['conv1']
model_6_1.conv1.bias.data = b_6_1['conv1']
model_6_1.conv2.weight.data = W_6_1['conv2']
model_6_1.conv2.bias.data = b_6_1['conv2']
model_6_1.conv3.weight.data = W_6_1['conv3']
model_6_1.conv3.bias.data = b_6_1['conv3']
model_6_1.t_conv1.weight.data = W_6_1['t_conv1']
model_6_1.t_conv1.bias.data = b_6_1['t_conv1']
model_6_1.t_conv2.weight.data = W_6_1['t_conv2']
model_6_1.t_conv3.weight.data = W_6_1['t_conv3']
model_6_1.conv_out.weight.data = W_6_1['conv_out']
model_6_1.conv_out.bias.data = b_6_1['conv_out']

# For model_6_2
model_6_2.conv1.weight.data = W_6_2['conv1']
model_6_2.conv1.bias.data = b_6_2['conv1']
model_6_2.conv2.weight.data = W_6_2['conv2']
model_6_2.conv2.bias.data = b_6_2['conv2']
model_6_2.conv3.weight.data = W_6_2['conv3']
model_6_2.conv3.bias.data = b_6_2['conv3']
model_6_2.t_conv1.weight.data = W_6_2['t_conv1']
model_6_2.t_conv1.bias.data = b_6_2['t_conv1']
model_6_2.t_conv2.weight.data = W_6_2['t_conv2']
model_6_2.t_conv3.weight.data = W_6_2['t_conv3']
model_6_2.conv_out.weight.data = W_6_2['conv_out']
model_6_2.conv_out.bias.data = b_6_2['conv_out']

# For model_7_1
model_7_1.conv1.weight.data = W_7_1['conv1']
model_7_1.conv1.bias.data = b_7_1['conv1']
model_7_1.conv2.weight.data = W_7_1['conv2']
model_7_1.conv2.bias.data = b_7_1['conv2']
model_7_1.conv3.weight.data = W_7_1['conv3']
model_7_1.conv3.bias.data = b_7_1['conv3']
model_7_1.t_conv1.weight.data = W_7_1['t_conv1']
model_7_1.t_conv1.bias.data = b_7_1['t_conv1']
model_7_1.t_conv2.weight.data = W_7_1['t_conv2']
model_7_1.t_conv3.weight.data = W_7_1['t_conv3']
model_7_1.conv_out.weight.data = W_7_1['conv_out']
model_7_1.conv_out.bias.data = b_7_1['conv_out']

# For model_7_2
model_7_2.conv1.weight.data = W_7_2['conv1']
model_7_2.conv1.bias.data = b_7_2['conv1']
model_7_2.conv2.weight.data = W_7_2['conv2']
model_7_2.conv2.bias.data = b_7_2['conv2']
model_7_2.conv3.weight.data = W_7_2['conv3']
model_7_2.conv3.bias.data = b_7_2['conv3']
model_7_2.t_conv1.weight.data = W_7_2['t_conv1']
model_7_2.t_conv1.bias.data = b_7_2['t_conv1']
model_7_2.t_conv2.weight.data = W_7_2['t_conv2']
model_7_2.t_conv3.weight.data = W_7_2['t_conv3']
model_7_2.conv_out.weight.data = W_7_2['conv_out']
model_7_2.conv_out.bias.data = b_7_2['conv_out']

# For model_8_1
model_8_1.conv1.weight.data = W_8_1['conv1']
model_8_1.conv1.bias.data = b_8_1['conv1']
model_8_1.conv2.weight.data = W_8_1['conv2']
model_8_1.conv2.bias.data = b_8_1['conv2']
model_8_1.conv3.weight.data = W_8_1['conv3']
model_8_1.conv3.bias.data = b_8_1['conv3']
model_8_1.t_conv1.weight.data = W_8_1['t_conv1']
model_8_1.t_conv1.bias.data = b_8_1['t_conv1']
model_8_1.t_conv2.weight.data = W_8_1['t_conv2']
model_8_1.t_conv3.weight.data = W_8_1['t_conv3']
model_8_1.conv_out.weight.data = W_8_1['conv_out']
model_8_1.conv_out.bias.data = b_8_1['conv_out']

# For model_8_2
model_8_2.conv1.weight.data = W_8_2['conv1']
model_8_2.conv1.bias.data = b_8_2['conv1']
model_8_2.conv2.weight.data = W_8_2['conv2']
model_8_2.conv2.bias.data = b_8_2['conv2']
model_8_2.conv3.weight.data = W_8_2['conv3']
model_8_2.conv3.bias.data = b_8_2['conv3']
model_8_2.t_conv1.weight.data = W_8_2['t_conv1']
model_8_2.t_conv1.bias.data = b_8_2['t_conv1']
model_8_2.t_conv2.weight.data = W_8_2['t_conv2']
model_8_2.t_conv3.weight.data = W_8_2['t_conv3']
model_8_2.conv_out.weight.data = W_8_2['conv_out']
model_8_2.conv_out.bias.data = b_8_2['conv_out']

# For model_9_1
model_9_1.conv1.weight.data = W_9_1['conv1']
model_9_1.conv1.bias.data = b_9_1['conv1']
model_9_1.conv2.weight.data = W_9_1['conv2']
model_9_1.conv2.bias.data = b_9_1['conv2']
model_9_1.conv3.weight.data = W_9_1['conv3']
model_9_1.conv3.bias.data = b_9_1['conv3']
model_9_1.t_conv1.weight.data = W_9_1['t_conv1']
model_9_1.t_conv1.bias.data = b_9_1['t_conv1']
model_9_1.t_conv2.weight.data = W_9_1['t_conv2']
model_9_1.t_conv3.weight.data = W_9_1['t_conv3']
model_9_1.conv_out.weight.data = W_9_1['conv_out']
model_9_1.conv_out.bias.data = b_9_1['conv_out']

# For model_9_2
model_9_2.conv1.weight.data = W_9_2['conv1']
model_9_2.conv1.bias.data = b_9_2['conv1']
model_9_2.conv2.weight.data = W_9_2['conv2']
model_9_2.conv2.bias.data = b_9_2['conv2']
model_9_2.conv3.weight.data = W_9_2['conv3']
model_9_2.conv3.bias.data = b_9_2['conv3']
model_9_2.t_conv1.weight.data = W_9_2['t_conv1']
model_9_2.t_conv1.bias.data = b_9_2['t_conv1']
model_9_2.t_conv2.weight.data = W_9_2['t_conv2']
model_9_2.t_conv3.weight.data = W_9_2['t_conv3']
model_9_2.conv_out.weight.data = W_9_2['conv_out']
model_9_2.conv_out.bias.data = b_9_2['conv_out']

# For model_10_1
model_10_1.conv1.weight.data = W_10_1['conv1']
model_10_1.conv1.bias.data = b_10_1['conv1']
model_10_1.conv2.weight.data = W_10_1['conv2']
model_10_1.conv2.bias.data = b_10_1['conv2']
model_10_1.conv3.weight.data = W_10_1['conv3']
model_10_1.conv3.bias.data = b_10_1['conv3']
model_10_1.t_conv1.weight.data = W_10_1['t_conv1']
model_10_1.t_conv1.bias.data = b_10_1['t_conv1']
model_10_1.t_conv2.weight.data = W_10_1['t_conv2']
model_10_1.t_conv3.weight.data = W_10_1['t_conv3']
model_10_1.conv_out.weight.data = W_10_1['conv_out']
model_10_1.conv_out.bias.data = b_10_1['conv_out']

# For model_10_2
model_10_2.conv1.weight.data = W_10_2['conv1']
model_10_2.conv1.bias.data = b_10_2['conv1']
model_10_2.conv2.weight.data = W_10_2['conv2']
model_10_2.conv2.bias.data = b_10_2['conv2']
model_10_2.conv3.weight.data = W_10_2['conv3']
model_10_2.conv3.bias.data = b_10_2['conv3']
model_10_2.t_conv1.weight.data = W_10_2['t_conv1']
model_10_2.t_conv1.bias.data = b_10_2['t_conv1']
model_10_2.t_conv2.weight.data = W_10_2['t_conv2']
model_10_2.t_conv3.weight.data = W_10_2['t_conv3']
model_10_2.conv_out.weight.data = W_10_2['conv_out']
model_10_2.conv_out.bias.data = b_10_2['conv_out']

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the size of the image
image_size = 28

# Generate random noise with the same size as MNIST images
random_noise = np.random.rand(image_size, image_size)
input_image = torch.tensor(random_noise).unsqueeze(0).unsqueeze(0).float()  # Add batch and channel dimensions

# Display the random noise image
plt.imshow(random_noise, cmap='gray')
plt.axis('off')
plt.show()

# %%
output_images = []

# Define the list of models
models = [model_10_2, model_10_1, model_9_2, model_9_1, model_8_2, model_8_1,
          model_7_2, model_7_1, model_6_2, model_6_1, model_5_2, model_5_1,
          model_4_2, model_4_1, model_3_2, model_3_1, model_2_2, model_2_1,
          model_1_2, model_1_1]


# Pass the input image through each model for 1 iteration
for model in models:
    # Pass the input image through the model
    output_image = model(input_image)
    
    # Store the output image
    output_images.append(output_image.clone())
    
    # Set the output of the current model as the input for the next iteration
    input_image = output_image.clone()

# %%
import matplotlib.pyplot as plt

# Define the number of rows and columns for subplots
num_rows = 4
num_cols = 5

# Create a new figure
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 12))

# Plot each output image
for i, output_image in enumerate(output_images):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].imshow(output_image.squeeze().cpu().detach().numpy(), cmap='gray')
    axes[row, col].axis('off')
    axes[row, col].set_title(f"Iteration {i+1}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Only one model trained on stronger denoising

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the size of the image
image_size = 28

# Generate random noise with the same size as MNIST images
random_noise = np.random.rand(image_size, image_size)
input_image = torch.tensor(random_noise).unsqueeze(0).unsqueeze(0).float()  # Add batch and channel dimensions

# Display the random noise image
plt.imshow(random_noise, cmap='gray')
plt.axis('off')
plt.show()

# %%
output_file_path = 'Output/output_dict.json'


with open(output_file_path, 'r') as f:
    output_dict_loaded = json.load(f)

for key, value in output_dict_loaded.items():
    # Check if the key is 'all_weights' or 'all_samples'
    if key in ['all_weights', 'all_samples']:
        # Convert the corresponding list to a tensor
        output_dict_loaded[key] = list_to_tensor(value)    
        

# get samples and weights from output_dict_loaded_1
samples_vector = output_dict_loaded['all_samples']
weights_vector = output_dict_loaded['all_weights']
weights = weights_vector[-1, :]
samples = samples_vector[-1, :, :]
weights = np.nan_to_num(weights)
wn = weights / sum(weights)

output_images = []
for i in range(20):
    positions = np.random.choice([i for i in range(N * K)], 1, replace=True, p=wn)
    parameter_vec = samples[:, positions]
    [W, b] = Vec2param(parameter_vec)
    model = ConvDenoiser()
    model.conv1.weight.data = W['conv1']
    model.conv1.bias.data = b['conv1']
    model.conv2.weight.data = W['conv2']
    model.conv2.bias.data = b['conv2']
    model.conv3.weight.data = W['conv3']
    model.conv3.bias.data = b['conv3']
    model.t_conv1.weight.data = W['t_conv1']
    model.t_conv1.bias.data = b['t_conv1']
    model.t_conv2.weight.data = W['t_conv2']
    model.t_conv3.weight.data = W['t_conv3']
    model.conv_out.weight.data = W['conv_out']
    model.conv_out.bias.data = b['conv_out']
    output_image = model(input_image)
    output_images.append(output_image.clone())
    input_image = output_image.clone()
    
# Define the number of rows and columns for subplots
num_rows = 4
num_cols = 5

# Create a new figure
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 12))

# Plot each output image
for i, output_image in enumerate(output_images):
    row = i // num_cols
    col = i % num_cols
    axes[row, col].imshow(output_image.squeeze().cpu().detach().numpy(), cmap='gray')
    axes[row, col].axis('off')
    axes[row, col].set_title(f"Iteration {i+1}")

plt.tight_layout()
plt.show()
